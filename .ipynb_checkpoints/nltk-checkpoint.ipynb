# %% [markdown]
# # reading: NLTK Book
# in this notebook i learn to use nltk & make notes following the [NLTK Book](https://www.nltk.org/book/). it uses the same setup and conda env as the other `.ipynb` in this folder: `normalization.ipynb`.

# %%
import nltk
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# ## exercises from chapter 1: language processing and python

# %% [markdown]
# ex. 3)

# %%
ls = ['Monty', 'Python']
ls * 3
# Out:
# ['Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python']

# %% [markdown]
# ex. 4)

# %%
len(text2) #pt 1 how many words in total
# Out:
# 141576

# %%
len(sorted(set(text2))) #pt 2 how many distinct vocab words
# Out:
# 6833

# %%
100 * text5.count('lol') / len(text5)
# Out:
# 1.5640968673628082

# %%
fdist1 = FreqDist(text2) #ch 1.3 code-along exe. 
print(text2)
fdist1.most_common(30)
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>
# [(',', 9397),
#  ('to', 4063),
#  ('.', 3975),
#  ('the', 3861),
#  ('of', 3565),
#  ('and', 3350),
#  ('her', 2436),
#  ('a', 2043),
#  ('I', 2004),
#  ('in', 1904),
#  ('was', 1846),
#  ('it', 1568),
#  ('"', 1506),
#  (';', 1419),
#  ('she', 1333),
#  ('be', 1305),
#  ('that', 1297),
#  ('for', 1234),
#  ('not', 1212),
#  ('as', 1179),
#  ('you', 1037),
#  ('with', 971),
#  ('had', 969),
#  ('his', 941),
#  ('he', 895),
#  ("'", 883),
#  ('have', 807),
#  ('at', 806),
#  ('by', 737),
#  ('is', 728)]
